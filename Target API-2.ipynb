# %% [markdown]
# ## Google Places API Call

# %%
import requests
import json

def get_target_store_locations(api_key):
    base_url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json'
    params = {
        'location': '37.7749,-122.4194',  # Example: San Francisco coordinates
        'radius': 50000,  # Radius in meters (adjust as needed)
        'keyword': 'Target store',
        'key': api_key
    }

    response = requests.get(base_url, params=params)
    if response.status_code == 200:
        data = response.json()
        return data.get('results', [])
    else:
        print(f'Error fetching data: {response.status_code}')
        return []

def print_store_locations(store_locations):
    for store in store_locations:
        print(f"Store Name: {store['name']}")
        print(f"Address: {store['vicinity']}")
#         print(f"Location: {store['geometry']['location']['lat']}, {store['geometry']['location']['lng']}")
        print()

if __name__ == "__main__":
    api_key = api_key
    store_locations = get_target_store_locations(api_key)
    if store_locations:
        print_store_locations(store_locations)
    else:
        print('No Target store locations found.')
# Out:
# Store Name: Target
# Address: 2004 El Camino Real, Santa Clara
#
# Store Name: Target
# Address: 789 Mission St, San Francisco
#
# Store Name: Target
# Address: 1057 Eastshore Hwy, Albany
#
# Store Name: Target
# Address: 298 W McKinley Ave, Sunnyvale
#
# Store Name: Target
# Address: 1555 40th St, Emeryville
#
# Store Name: Target
# Address: 1775 E Bayshore Rd, East Palo Alto
#
# Store Name: Target
# Address: 4500 Macdonald Ave, Richmond
#
# Store Name: Target
# Address: 5001 Junipero Serra Blvd, Colma
#
# Store Name: Target
# Address: 39201 Fremont Blvd, Fremont
#
# Store Name: Target
# Address: 1150 El Camino Real, San Bruno
#
# Store Name: Target
# Address: 2675 Geary Blvd, San Francisco
#
# Store Name: Target
# Address: 2220 Bridgepointe Pkwy, San Mateo
#
# Store Name: Target
# Address: 555 Showers Dr, Mountain View
#
# Store Name: Target
# Address: 1871 N Main St, Walnut Creek
#
# Store Name: Target
# Address: 2800 Dublin Blvd, Dublin
#
# Store Name: Target
# ...

# %%
import requests
import json

def get_target_store_locations(api_key):
    base_url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json'
    params = {
        'location': '40.7608,-111.8910',  # Example: San Francisco coordinates
        'radius': 1000000,  # Radius in meters (adjust as needed)
        'keyword': 'Target store',
        'key': api_key
    }

    response = requests.get(base_url, params=params)
    if response.status_code == 200:
        data = response.json()
        return data.get('results', [])
    else:
        print(f'Error fetching data: {response.status_code}')
        return []

def print_store_locations(store_locations):
    for store in store_locations:
        print(f"Store Name: {store['name']}")
        print(f"Address: {store['vicinity']}")
#         print(f"Location: {store['geometry']['location']['lat']}, {store['geometry']['location']['lng']}")
        print()

if __name__ == "__main__":
    api_key = 'AIzaSyBn6VHlAiUIZW6_QQ5DYwzJ7-2WaxRsqvI'
    store_locations = get_target_store_locations(api_key)
    if store_locations:
        print_store_locations(store_locations)
    else:
        print('No Target store locations found.')
# Out:
# Store Name: Target
# Address: 1110 S 300 W, Salt Lake City
#
# Store Name: Target
# Address: 10130 S State St, Sandy
#
# Store Name: Target
# Address: 608 W Main St, American Fork
#
# Store Name: Target
# Address: 11525 Pkwy Plaza Dr, South Jordan
#
# Store Name: Target
# Address: 5518 High Market Dr, West Valley City
#
# Store Name: Target
# Address: 200 N Marketplace Dr, Centerville
#
# Store Name: Target
# Address: 2236 S 1300 E Ste D-1, Salt Lake City
#
# Store Name: Target
# Address: 7779 Jordan Landing Blvd, West Jordan
#
# Store Name: Target
# Address: 815 W 2000 N, Layton
#
# Store Name: Target
# Address: 7025 Park Centre Dr, Cottonwood Heights
#
# Store Name: Target
# Address: 1135 W Riverdale Rd, Riverdale
#
# Store Name: Target
# Address: 5800 S Redwood Rd, Taylorsville
#
# Store Name: Target Grocery
# Address: 10130 S State St, Sandy
#
# Store Name: Target Grocery
# Address: 7025 Park Centre Dr, Salt Lake City
#
# Store Name: Target Grocery
# ...

# %%
import requests
import json
api_key = 'AIzaSyBn6VHlAiUIZW6_QQ5DYwzJ7-2WaxRsqvI'

def get_target_store_locations(api_key, state):
    base_url = 'https://maps.googleapis.com/maps/api/place/textsearch/json'
    params = {
        'query': f'Target store in {state}',  # Include the state in the query
        'key': api_key
    }

    response = requests.get(base_url, params=params)
    if response.status_code == 200:
        data = response.json()
        return data.get('results', [])
    else:
        print(f'Error fetching data: {response.status_code}')
        return []

# Example usage
api_key = 'AIzaSyBn6VHlAiUIZW6_QQ5DYwzJ7-2WaxRsqvI'
state = 'California'  # Change this to the desired state
target_stores = get_target_store_locations(api_key, state)
for store in target_stores:
    print(store['name'], store['formatted_address'])
# Out:
# Target 29676 Rancho California Rd, Temecula, CA 92591, United States
# Target 2040 California Ave, Sand City, CA 93955, United States
# Target 3535 S La Cienega Blvd, Los Angeles, CA 90016, United States
# Target 78935 CA-111, La Quinta, CA 92253, United States
# Target 1701 N Gaffey St, San Pedro, CA 90731, United States
# Target 1000 Commerce Ave, Atwater, CA 95301, United States
# Target 72549 CA-111, Palm Desert, CA 92260, United States
# Target 223 Betteravia Rd, Santa Maria, CA 93454, United States
# Target 990 Avenida Vista Hermosa, San Clemente, CA 92673, United States
# Target 800 New Los Angeles Ave, Moorpark, CA 93021, United States
# Target 2004 El Camino Real, Santa Clara, CA 95050, United States
# Target 950 Groveland Ln, Lincoln, CA 95648, United States
# Target 41040 California Oaks Rd, Murrieta, CA 92562, United States
# Target 133 General Stilwell Dr, Marina, CA 93933, United States
# Target 16858 Golden Vly Pkwy, Lathrop, CA 95330, United States
# ...

# %%
store_list_3 = []
for store in target_stores:
    store_list_3.append(store['formatted_address'])

# %%
len(store_list_3)
# Out:
# 20

# %%
import requests
import json

def get_target_store_locations(api_key, state):
    base_url = 'https://maps.googleapis.com/maps/api/place/textsearch/json'
    params = {
        'query': f'Target store in {state}',  # Include the state in the query
        'key': api_key
    }

    all_results = []
    next_page_token = None

    while True:
        if next_page_token:
            params['pagetoken'] = next_page_token

        response = requests.get(base_url, params=params)
        if response.status_code == 200:
            data = response.json()
            results = data.get('results', [])
            all_results.extend(results)

            next_page_token = data.get('next_page_token')
            if not next_page_token:
                break  # No more pages to fetch
        else:
            print(f'Error fetching data: {response.status_code}')
            break

    return all_results

# Example usage
api_key = 'AIzaSyBn6VHlAiUIZW6_QQ5DYwzJ7-2WaxRsqvI'
state = 'California'  # Change this to the desired state
target_stores = get_target_store_locations(api_key, state)
for store in target_stores:
    print(store['name'], store['formatted_address'])
# Out:
# Target 29676 Rancho California Rd, Temecula, CA 92591, United States
# Target 2040 California Ave, Sand City, CA 93955, United States
# Target 3535 S La Cienega Blvd, Los Angeles, CA 90016, United States
# Target 78935 CA-111, La Quinta, CA 92253, United States
# Target 1701 N Gaffey St, San Pedro, CA 90731, United States
# Target 72549 CA-111, Palm Desert, CA 92260, United States
# Target 1000 Commerce Ave, Atwater, CA 95301, United States
# Target 223 Betteravia Rd, Santa Maria, CA 93454, United States
# Target 950 Groveland Ln, Lincoln, CA 95648, United States
# Target 990 Avenida Vista Hermosa, San Clemente, CA 92673, United States
# Target 800 New Los Angeles Ave, Moorpark, CA 93021, United States
# Target 16858 Golden Vly Pkwy, Lathrop, CA 95330, United States
# Target 133 General Stilwell Dr, Marina, CA 93933, United States
# Target 2004 El Camino Real, Santa Clara, CA 95050, United States
# Target 4707 Pacific Ave, Stockton, CA 95207, United States
# ...

# %%
import pandas as pd

coordinates = pd.read_csv('/Users/kimbuesser/Downloads/us-state-capitals.csv')
coordinates
# Out:
#               name     description   latitude   longitude
# 0          Alabama      Montgomery  32.377716  -86.300568
# 1           Alaska          Juneau  58.301598 -134.420212
# 2          Arizona         Phoenix  33.448143 -112.096962
# 3         Arkansas     Little Rock  34.746613  -92.288986
# 4       California      Sacramento  38.576668 -121.493629
# 5         Colorado          Denver  39.739227 -104.984856
# 6      Connecticut    Hartford<br>  41.764046  -72.682198
# 7         Delaware           Dover  39.157307  -75.519722
# 8           Hawaii        Honolulu  21.307442 -157.857376
# 9          Florida     Tallahassee  30.438118  -84.281296
# 10         Georgia     Atlanta<br>  33.749027  -84.388229
# 11           Idaho           Boise  43.617775 -116.199722
# 12        Illinois     Springfield  39.798363  -89.654961
# 13         Indiana    Indianapolis  39.768623  -86.162643
# 14            Iowa      Des Moines  41.591087  -93.603729
# ...

# %%
coordinates["long_lat"] = coordinates["latitude"].astype(str) + "," + coordinates["longitude"].astype(str)
coordinates
# Out:
#               name     description   latitude   longitude  \
# 0          Alabama      Montgomery  32.377716  -86.300568
# 1           Alaska          Juneau  58.301598 -134.420212
# 2          Arizona         Phoenix  33.448143 -112.096962
# 3         Arkansas     Little Rock  34.746613  -92.288986
# 4       California      Sacramento  38.576668 -121.493629
# 5         Colorado          Denver  39.739227 -104.984856
# 6      Connecticut    Hartford<br>  41.764046  -72.682198
# 7         Delaware           Dover  39.157307  -75.519722
# 8           Hawaii        Honolulu  21.307442 -157.857376
# 9          Florida     Tallahassee  30.438118  -84.281296
# 10         Georgia     Atlanta<br>  33.749027  -84.388229
# 11           Idaho           Boise  43.617775 -116.199722
# 12        Illinois     Springfield  39.798363  -89.654961
# 13         Indiana    Indianapolis  39.768623  -86.162643
# 14            Iowa      Des Moines  41.591087  -93.603729
# ...

# %%
coordinate_list = coordinates['long_lat']. tolist()
coordinate_list
# Out:
# ['32.377716,-86.300568',
#  '58.301598,-134.420212',
#  '33.448143,-112.096962',
#  '34.746613,-92.288986',
#  '38.576668,-121.493629',
#  '39.739227,-104.984856',
#  '41.764046,-72.682198',
#  '39.157307,-75.519722',
#  '21.307442,-157.857376',
#  '30.438118,-84.281296',
#  '33.749027,-84.388229',
#  '43.617775,-116.199722',
#  '39.798363,-89.654961',
#  '39.768623,-86.162643',
#  '41.591087,-93.603729',
#  '39.048191,-95.677956',
#  '38.186722,-84.875374',
#  '30.457069,-91.187393',
#  '44.307167,-69.781693',
#  '38.978764,-76.490936',
#  '42.358162,-71.063698',
#  '42.733635,-84.555328',
#  '44.955097,-93.102211',
#  '32.303848,-90.182106',
#  '38.579201,-92.172935',
#  '46.585709,-112.018417',
#  '40.808075,-96.699654',
#  '39.163914,-119.766121',
#  '43.206898,-71.537994',
#  '40.220596,-74.769913',
#  '35.68224,-105.939728',
#  '35.78043,-78.639099',
#  '46.82085,-100.783318',
#  '42.652843,-73.757874',
#  '39.961346,-82.999069',
#  '35.492207,-97.503342',
# ...

# %%
import requests
import json

def get_target_store_locations(coordinates):
    base_url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json'
    params = {
        'location': coordinates,  # Example: San Francisco coordinates
        'radius': 5000000,  # Radius in meters (adjust as needed)
        'keyword': 'Target store',
        'key': 'AIzaSyBn6VHlAiUIZW6_QQ5DYwzJ7-2WaxRsqvI'
    }

    response = requests.get(base_url, params=params)
    if response.status_code == 200:
        data = response.json()
        return data.get('results', [])
    else:
        print(f'Error fetching data: {response.status_code}')
        return []

# def print_store_locations(store_locations):
#     for store in store_locations:
#         print(f"Store Name: {store['name']}")
#         print(f"Address: {store['vicinity']}")
# #         print(f"Location: {store['geometry']['location']['lat']}, {store['geometry']['location']['lng']}")
#         print()

# if __name__ == "__main__":
#     for coordinate in coordinate_list:
# #     api_key = 'AIzaSyBn6VHlAiUIZW6_QQ5DYwzJ7-2WaxRsqvI'
#         store_locations = get_target_store_locations(api_key)
#     if store_locations:
#         print_store_locations(store_locations)
#     else:
#         print('No Target store locations found.')

# %%
target_stores_2 = []
for coordinate in coordinate_list:
    target_stores_2.append(get_target_store_locations(coordinate))

# %%
for store in target_stores_2:
        print(f"Store Name: {store['name']}")
        print(f"Address: {store['vicinity']}")
#         print(f"Location: {store['geometry']['location']['lat']}, {store['geometry']['location']['lng']}")
        print()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
#       1 for store in target_stores_2:
# ----> 2         print(f"Store Name: {store['name']}")
#       3         print(f"Address: {store['vicinity']}")
#       4 #         print(f"Location: {store['geometry']['location']['lat']}, {store['geometry']['location']['lng']}")
#
# TypeError: list indices must be integers or slices, not str

# %%
item = get_target_store_locations('41.140259,-104.820236')
item[1]['vicinity']
# Out:
# '1708 Dell Range Blvd, Cheyenne'

# %%
list_of_target_stores = []
for store in target_stores_2:
    for item in store:
        print(item['vicinity'])
# Out:
# 2576 Berryhill Rd, Montgomery
# 2754 Legends Pkwy, Prattville
# 2754 Legends Pkwy, Prattville
# 175 S Franklin St STE 101, Juneau
# 9107 Mendenhall Mall Rd # 301, Juneau
# 497 S Franklin St, Juneau
# 118 Seward St, Juneau
# 489 S Franklin St, Juneau
# 234 Seward St, Juneau
# 110 N Franklin St, Juneau
# 215 Ferry Way, Juneau
# 9105 Mendenhall Mall Rd Suite 170, Juneau
# 432 S Franklin St, Juneau
# Valentine Building, 109 Seward St, Juneau
# 9105 Mendenhall Mall Road Mendenhall Mall, Ste. 360, Juneau
# 1625 E Camelback Rd, Phoenix
# 5715 N 19th Ave, Phoenix
# 10404 N 43rd Ave, Glendale
# 4515 E Thomas Rd, Phoenix
# 2140 E Baseline Rd, Phoenix
# 15444 N Frank Lloyd Wright Blvd, Scottsdale
# 9350 W Northern Ave, Glendale
# 1515 E Warner Rd, Gilbert
# 3777 S Arizona Ave, Chandler
# 3931 S Gilbert Rd, Gilbert
# 12602 N Paradise Village Pkwy W, Phoenix
# 3425 W Frye Rd, Chandler
# 21001 N Tatum Blvd Suite 20, Phoenix
# 13731 W Bell Rd, Surprise
# 4734 E Ray Rd, Phoenix
# ...

# %%
df = pd.DataFrame(list_of_target_stores)

df.columns =['combined_address']
df
# Out:
#                         combined_address
# 0          2576 Berryhill Rd, Montgomery
# 1          2754 Legends Pkwy, Prattville
# 2          2754 Legends Pkwy, Prattville
# 3    Symal House, 423 Edgware Rd, London
# 4                 Biggin Hill, Westerham
# ..                                   ...
# 623                4301 Lien Rd, Madison
# 624             750 Hilldale Wy, Madison
# 625                4301 Lien Rd, Madison
# 626       1708 Dell Range Blvd, Cheyenne
# 627       1708 Dell Range Blvd, Cheyenne
#
# [628 rows x 1 columns]

# %%
df[['Street Address', 'City']] = df['combined_address'].str.split(',', expand=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [51], in <cell line: 1>()
# ----> 1 df[['Street Address', 'City']] = df['combined_address'].str.split(',', expand=True)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3643, in DataFrame.__setitem__(self, key, value)
#    3641     self._setitem_frame(key, value)
#    3642 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3643     self._setitem_array(key, value)
#    3644 elif isinstance(value, DataFrame):
#    3645     self._set_item_frame_value(key, value)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3685, in DataFrame._setitem_array(self, key, value)
#    3680 else:
#    3681     # Note: unlike self.iloc[:, indexer] = value, this will
#    3682     #  never try to overwrite values inplace
#    3684     if isinstance(value, DataFrame):
# ...

# %%
import pandas as pd

df[['Street_Address', 'City_State']] = df['combined_address'].str.split(', ', n=1, expand=True)

# Print the updated DataFrame
print(df)
# Out:
#                         combined_address        Street_Address  \
# 0          2576 Berryhill Rd, Montgomery     2576 Berryhill Rd
# 1          2754 Legends Pkwy, Prattville     2754 Legends Pkwy
# 2          2754 Legends Pkwy, Prattville     2754 Legends Pkwy
# 3    Symal House, 423 Edgware Rd, London           Symal House
# 4                 Biggin Hill, Westerham           Biggin Hill
# ..                                   ...                   ...
# 623                4301 Lien Rd, Madison          4301 Lien Rd
# 624             750 Hilldale Wy, Madison       750 Hilldale Wy
# 625                4301 Lien Rd, Madison          4301 Lien Rd
# 626       1708 Dell Range Blvd, Cheyenne  1708 Dell Range Blvd
# 627       1708 Dell Range Blvd, Cheyenne  1708 Dell Range Blvd
#
#                  City_State
# 0                Montgomery
# 1                Prattville
# 2                Prattville
# 3    423 Edgware Rd, London
# 4                 Westerham
# ..                      ...
# ...

# %%
df.to_csv('/Users/kimbuesser/Downloads/target_addresses.csv')

# %%
df['combined_address'].count()
# Out:
# 628

# %%
list_of_target_stores = []
for store in target_stores_2:
    for item in store:
        list_of_target_stores.append(item['vicinity'])

# %%
len(list_of_target_stores)
# Out:
# 628

# %%
type(store_locations)
# Out:
# list

# %%
target_locations = []
for store in store_locations:
    target_locations.append(store['vicinity'])

# %%
target_locations
# Out:
# ['2004 El Camino Real, Santa Clara',
#  '789 Mission St, San Francisco',
#  '1057 Eastshore Hwy, Albany',
#  '298 W McKinley Ave, Sunnyvale',
#  '1555 40th St, Emeryville',
#  '1775 E Bayshore Rd, East Palo Alto',
#  '4500 Macdonald Ave, Richmond',
#  '5001 Junipero Serra Blvd, Colma',
#  '39201 Fremont Blvd, Fremont',
#  '1150 El Camino Real, San Bruno',
#  '2675 Geary Blvd, San Francisco',
#  '2220 Bridgepointe Pkwy, San Mateo',
#  '555 Showers Dr, Mountain View',
#  '43950 Pacific Commons Blvd, Fremont',
#  '1871 N Main St, Walnut Creek',
#  '2800 Dublin Blvd, Dublin',
#  '2485 El Camino Real, Redwood City',
#  '2700 5th St, Alameda',
#  '2155 Morrill Ave, San Jose',
#  '125 Shoreline Pkwy, San Rafael']

# %%
import requests
YOUR_API_KEY = 

response = requests.get('https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input=Museum%20of%20Contemporary%20Art%20Australia&inputtype=textquery&fields=formatted_address%2Cname%2Crating%2Copening_hours%2Cgeometry&key=YOUR_API_KEY')
print(response.text)
# Out:
# {
#    "candidates" : [],
#    "error_message" : "The provided API key is invalid.",
#    "status" : "REQUEST_DENIED"
# }

# %% [markdown]
# ## Yelp API

# %%
import requests

# Define your Yelp API key
api_key = '2roPSP___vJtBJOZuK_vsvWehpzc1WZiZTd3YFTgLSSiSC5xNBQxJZwHPsM1Vn_NI9KWJ8Y6TlFAqMgdUAJAcekp38_aPqwyz6ZtiEkZnyupfdSDuZsUBHHE3uAKZnYx'

# Define the base URL for the Yelp API
base_url = "https://api.yelp.com/v3/businesses/search"

# Define the search parameters
params = {
    "term": "Target store",
    "location": "San Francisco",  # Replace 'Your Location' with the desired location
    "limit": 50,  # Maximum number of results to return
}

# Set the authorization header with your API key
headers = {
    "Authorization": f"Bearer {api_key}"
}

# Send a GET request to the API
response = requests.get(base_url, params=params, headers=headers)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the JSON response
    data = response.json()
    
    # Extract and print the addresses from the response
    for business in data.get('businesses', []):
        address = business.get('location', {}).get('address1')
        if address:
            print(address)
else:
    print("Error:", response.status_code, response.text)
# Out:
# 2675 Geary Blvd
# 789 Mission St
# 285 Winston Dr
# 100 Westlake Ctr
# 5001 Junipero Serra Blvd
# 133 Serramonte Ctr
# 170 Ofarrell St
# 22 Peace Plz
# 845 Market St
# 610 Old Mason St
# 1590 Bryant St
# 150 Stockton St
# 1310 9th Ave
# 1981 Union St
# 130 A Serramonte Ctr
# 1415 Haight St
# 2085 Chestnut St
# 2448 Fillmore St
# 545 Valencia St
# 233 Geary St
# 840 Brannan St
# 240 Stockton St
# 24 Willie Mays Plz
# 1701 Taraval  St
# 1555 Haight St
# 1746 Post St
# 1901 Fillmore St
# 220 Fillmore St
# 1813 Polk St
# 1612 Stockton St
# 1621 Haight St
# 506 Hayes St
# 630 Irving St
# 300 Grant Ave
# 250 Post St
# 461 Valencia St
# 61 Post St
# 1545 Sloat Blvd
# 1210 Valencia St
# 3575 Sacramento St
# 1653 Haight St
# 799 Market St
# 680 8th St
# 350 Post St
# 1543 Haight St
# 569 Valencia St
# 572 Hayes St
# 1015 Market St
# 4300 Geary Blvd
# 1364 Haight St

# %%
import requests

# Define your Yelp API key
api_key = '2roPSP___vJtBJOZuK_vsvWehpzc1WZiZTd3YFTgLSSiSC5xNBQxJZwHPsM1Vn_NI9KWJ8Y6TlFAqMgdUAJAcekp38_aPqwyz6ZtiEkZnyupfdSDuZsUBHHE3uAKZnYx'

# Define the base URL for the Yelp API
base_url = "https://api.yelp.com/v3/businesses/search"

# Define the search parameters
params = {
    "term": "Target store",
    "location": "San Francisco",  # Replace 'Your Location' with the desired location
#     "limit": 50,  # Maximum number of results to return
}

# Set the authorization header with your API key
headers = {
    "Authorization": f"Bearer {api_key}"
}

# Send a GET request to the API
response = requests.get(base_url, params=params, headers=headers)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the JSON response
    data = response.json()
    
    # Extract and print the addresses from the response
    for business in data.get('businesses', []):
        address = business.get('location', {}).get('address1')
        if address:
            print(address)
else:
    print("Error:", response.status_code, response.text)
# Out:
# 2675 Geary Blvd
# 789 Mission St
# 285 Winston Dr
# 100 Westlake Ctr
# 5001 Junipero Serra Blvd
# 133 Serramonte Ctr
# 170 Ofarrell St
# 22 Peace Plz
# 845 Market St
# 610 Old Mason St
# 1590 Bryant St
# 150 Stockton St
# 1310 9th Ave
# 1981 Union St
# 130 A Serramonte Ctr
# 1415 Haight St
# 2085 Chestnut St
# 2448 Fillmore St
# 545 Valencia St
# 233 Geary St

# %% [markdown]
# ## Here (Radar) API

# %%
import requests

# Replace 'YOUR_APP_ID' and 'YOUR_APP_CODE' with your actual Here API credentials
app_id = 'YOUR_APP_ID'
app_code = 'YOUR_APP_CODE'

# Define the base URL for the Here Places API
base_url = "https://places.api.here.com/places/v1/discover/search"

# Define the search parameters
params = {
    "at": "latitude,longitude",  # Replace with the coordinates of your desired location
    "q": "Target",
    "apiKey": f"{app_id}:{app_code}",
}

# Send a GET request to the Places API
response = requests.get(base_url, params=params)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the JSON response
    data = response.json()
    
    # Extract and print the store locations
    for item in data.get('results', []):
        address = item.get('address', {}).get('label')
        if address:
            print(address)
else:
    print("Error:", response.status_code, response.text)

# %% [markdown]
# ## OpenStreetMap API

# %%
import requests

# Define the URL for the OpenStreetMap Nominatim API
base_url = "https://nominatim.openstreetmap.org/search"

# Define the search query parameters
params = {
    "q": "Target",
    "format": "json",
}

# Send a GET request to the API
response = requests.get(base_url, params=params)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the JSON response
    data = response.json()
    
    # Extract and print the addresses from the response
    for item in data:
        address = item.get('display_name', 'Address not available')
        print(address)
else:
    print("Error:", response.status_code, response.text)
# Out:
# Target, Vichy, Allier, Auvergne-Rhône-Alpes, France métropolitaine, 03140, France
# Target, Angeles, Central Luzon, 2023, Philippines
# Target, Spring Valley, Clark County, Nevada, United States
# Target, Oceanside, San Diego County, California, United States
# Target, Eureka, Humboldt County, California, United States
# Target, St. Cloud, Benton County, Minnesota, United States
# Target, Sayville, Town of Islip, Suffolk County, New York, United States
# Target, Ohio County, West Virginia, United States
# Target, 15025, Ballwin, Saint Louis County, Missouri, 63011, United States

# %% [markdown]
# # Webscrape

# %% [markdown]
# ## Beautiful Soup (Unsuccessful because address not in webpage html)

# %%
import requests
from bs4 import BeautifulSoup

def scrape_target_store_addresses(store_url):
    response = requests.get(store_url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        address_elements = soup.find_all('div', class_='Address')
        addresses = [address.text.strip() for address in address_elements]
        return addresses
    else:
        print(f'Error fetching data from {store_url}: {response.status_code}')
        return []

if __name__ == "__main__":
    target_store_url = 'https://www.target.com/store-locator/find-stores'
    store_addresses = scrape_target_store_addresses(target_store_url)
    if store_addresses:
        print("Target Store Addresses:")
        for address in store_addresses:
            print(address)
    else:
        print('No addresses found.')
# Out:
# No addresses found.

# %%
import requests
from bs4 import BeautifulSoup

def scrape_target_store_addresses(store_locator_url):
    response = requests.get(store_locator_url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        store_elements = soup.find_all('div', class_='styles__store___1g8ex')
        addresses = []

        for store in store_elements:
            address_element = store.find('div', class_='styles__address___1FhjP')
            if address_element:
                addresses.append(address_element.text.strip())
        
        return addresses
    else:
        print(f'Error fetching data from {store_locator_url}: {response.status_code}')
        return []

if __name__ == "__main__":
    target_store_locator_url = 'https://www.target.com/store-locator/find-stores'
    store_addresses = scrape_target_store_addresses(target_store_locator_url)
    if store_addresses:
        print("Target Store Addresses:")
        for address in store_addresses:
            print(address)
    else:
        print('No addresses found.')
# Out:
# No addresses found.

# %%
import requests
from lxml import html

def extract_addresses_from_target_page(url):
    response = requests.get(url)
    if response.status_code == 200:
        tree = html.fromstring(response.content)
        address_elements = tree.xpath('//*[@id="__next"]/div[4]/div/div[3]/div[1]/div/div/span/a[1]/text()')
        addresses = [address.strip() for address in address_elements]
        return addresses
    else:
        print(f'Error fetching data from {url}: {response.status_code}')
        return []

if __name__ == "__main__":
    target_url = 'https://www.target.com/store-locator/find-stores'  # Replace with the actual Target store locator URL
    store_addresses = extract_addresses_from_target_page(target_url)
    if store_addresses:
        print("Target Store Addresses:")
        for address in store_addresses:
            print(address)
    else:
        print('No addresses found.')
# Out:
# No addresses found.

# %%
import requests
from lxml import html

def extract_addresses_from_target_page(url):
    response = requests.get(url)
    if response.status_code == 200:
        tree = html.fromstring(response.content)
        address_elements = tree.cssselect('#__next > div:nth-child(5) > div > div.h-display-flex.h-flex-wrap.h-padding-h-tight > div:nth-child(1) > div > div > span > a:nth-child(1)')
        addresses = [address.text_content().strip() for address in address_elements]
        return addresses
    else:
        print(f'Error fetching data from {url}: {response.status_code}')
        return []

if __name__ == "__main__":
    target_url = 'https://www.target.com/store-locator/find-stores'  # Replace with the actual Target store locator URL
    store_addresses = extract_addresses_from_target_page(target_url)
    if store_addresses:
        print("Target Store Addresses:")
        for address in store_addresses:
            print(address)
    else:
        print('No addresses found.')
# Out:
# No addresses found.

# %%
# extracting target addresses

addresses_src = soup.find_all('a',{'class', 'Link__StyledLink-sc-4b9qcv-0 fUrQXY h-text-grayDarkest'})

addresses_src
address_list = []

for val in addresses_src:
    address_list.append(val.get_text())
address_list

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.target.com/store-locator/find-stores'

# %%
page = requests.get(url)

soup = BeautifulSoup(page.text, 'html')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=2, interactive-widget=overlays-content" name="viewport"/>
#   <title>
#    Stores Near Me : Target
#   </title>
#   <link href="https://www.target.com/store-locator/find-stores" rel="canonical"/>
#   <meta content="Find a Target store near you quickly with the Target Store Locator. Store hours, directions, addresses and phone numbers available for more than 1800 Target store locations across the US." name="description"/>
#   <meta content="Target store locator" name="keywords"/>
#   <meta content="index, follow" name="robots"/>
#   <meta content="7" name="next-head-count"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="x-ua-compatible"/>
#   <link crossorigin="anonymous" href="https://assets.targetimg1.com" rel="preconnect"/>
#   <link href="https://assets.targetimg1.com" rel="preconnect"/>
# ...

# %%
<a href="https://www.bing.com/maps?ss=Target%2C+1110+S+300+W%2C+Salt+Lake+City%2C+UT+84101-3053" target="_blank" aria-label="bing maps 1110 S 300 W, Salt Lake City, UT 84101-3053" class="styles__StyledLink-sc-vpsldm-0 eqjfDm h-text-grayDarkest" data-test="@store-locator/StoreAddress" rel="noopener">1110 S 300 W, Salt Lake City, UT 84101-3053</a>

# %%
<span class="h-display-inline-block"><a href="https://www.bing.com/maps?ss=Target%2C+7025+S+Park+Centre+Dr%2C+Salt+Lake+City%2C+UT+84121-6619" target="_blank" aria-label="bing maps 7025 S Park Centre Dr, Salt Lake City, UT 84121-6619" class="styles__StyledLink-sc-vpsldm-0 eqjfDm h-text-grayDarkest" data-test="@store-locator/StoreAddress" rel="noopener">7025 S Park Centre Dr, Salt Lake City, UT 84121-6619</a><div data-test="@store-locator/StoreCard/StoreCardHours" class="Card__StoreHours-sc-6da7hu-3 DqJtv">Open today: 7:00am - 10:00pm</div><a href="tel:+18012552292" class="styles__StyledLink-sc-vpsldm-0 eqjfDm h-text-grayDarkest " data-test="@store-locator/StorePhoneNumberLink">801-255-2292</a></span>

# %%
<div data-test="@store-locator/StoreCard" class="Card-sc-1t4yyi7-0 fbNdpO"><span class="Card__StoreCardHeading-sc-6da7hu-2 ifbVDI"><a class="styles__StyledLink-sc-vpsldm-0 bNbRSS" href="/sl/fort-union/1751"><h3 class="styles__StyledHeading-sc-1xmf98v-0 Card__StoreCardTitle-sc-6da7hu-0 eeTouF hKQQyO" data-test="@store-locator/StoreCard/StoreCardTitle">Fort Union<span class="h-sr-only">store details</span></h3></a></span><hr class="h-margin-t-x2"><div class="h-margin-b-tight"><span class="h-display-inline-block"><a href="https://www.bing.com/maps?ss=Target%2C+7025+S+Park+Centre+Dr%2C+Salt+Lake+City%2C+UT+84121-6619" target="_blank" aria-label="bing maps 7025 S Park Centre Dr, Salt Lake City, UT 84121-6619" class="styles__StyledLink-sc-vpsldm-0 eqjfDm h-text-grayDarkest" data-test="@store-locator/StoreAddress" rel="noopener">7025 S Park Centre Dr, Salt Lake City, UT 84121-6619</a><div data-test="@store-locator/StoreCard/StoreCardHours" class="Card__StoreHours-sc-6da7hu-3 DqJtv">Open today: 7:00am - 10:00pm</div><a href="tel:+18012552292" class="styles__StyledLink-sc-vpsldm-0 eqjfDm h-text-grayDarkest " data-test="@store-locator/StorePhoneNumberLink">801-255-2292</a></span><div class="Card__CardButtons-sc-6da7hu-1 hOHCme"><a aria-label="Store info for Fort Union" class="styles__StyledBaseButtonInternal-sc-ysboml-0 styles__ButtonSecondary-sc-125aivg-0 brTHah bxLMor" href="/sl/fort-union/1751">store info</a><button type="button" aria-label="Shop this store Fort Union" data-test="@store-locator/StoreCard/MakeItMyStoreBtn" class="styles__StyledBaseButtonInternal-sc-ysboml-0 styles__ButtonSecondary-sc-125aivg-0 brTHah bxLMor">shop this store</button></div></div></div>

# %%
print((soup.find('a')).prettify())
# Out:
# <a class="styles__SkipLink-sc-ri4hs3-0 ehpoVk h-sr-only h-sr-only-focusable" data-command="content" href="#content">
#  skip to main content
# </a>

# %%
print((soup.find('div')).prettify())
# Out:
# <div id="__next">
#  <button aria-hidden="true" class="styles__StyledLink-sc-vpsldm-0 eqjfDm h-display-flex" id="staticShellLink" tabindex="-1" type="button">
#  </button>
#  <div data-test="skipLinks" id="skipLinks">
#   <a class="styles__SkipLink-sc-ri4hs3-0 ehpoVk h-sr-only h-sr-only-focusable" data-command="content" href="#content">
#    skip to main content
#   </a>
#   <a class="styles__SkipLink-sc-ri4hs3-0 ehpoVk h-sr-only h-sr-only-focusable" data-command="footer" href="#footerHeader">
#    skip to footer
#   </a>
#  </div>
#  <div class="styles__UtilityHeaderWrapper-sc-15b7d8q-0 Hqpxr">
#   <div class="styles__UtilityHeaderContainer-sc-ujzcd7-0 ijBhbt l-container-fixed">
#    <div class="styles__FlexColumn-sc-jn7faf-0 fJvKWQ">
#     <div class="styles__StyledZipPlaceholder-sc-ujzcd7-8 HxwOh">
#     </div>
#    </div>
#    <div class="styles__FlexColumn-sc-jn7faf-0 dnbTbk">
#     <div class="styles__UtilityNavWrapper-sc-jn7faf-1 kEHJjD h-flex-align-center">
# ...

# %%
<div class="h-margin-b-tight"><span class="h-display-inline-block"><a href="https://www.bing.com/maps?ss=Target%2C+7025+S+Park+Centre+Dr%2C+Salt+Lake+City%2C+UT+84121-6619" target="_blank" aria-label="bing maps 7025 S Park Centre Dr, Salt Lake City, UT 84121-6619" class="styles__StyledLink-sc-vpsldm-0 eqjfDm h-text-grayDarkest" data-test="@store-locator/StoreAddress" rel="noopener">7025 S Park Centre Dr, Salt Lake City, UT 84121-6619</a><div data-test="@store-locator/StoreCard/StoreCardHours" class="Card__StoreHours-sc-6da7hu-3 DqJtv">Open today: 7:00am - 10:00pm</div><a href="tel:+18012552292" class="styles__StyledLink-sc-vpsldm-0 eqjfDm h-text-grayDarkest " data-test="@store-locator/StorePhoneNumberLink">801-255-2292</a></span><div class="Card__CardButtons-sc-6da7hu-1 hOHCme"><a aria-label="Store info for Fort Union" class="styles__StyledBaseButtonInternal-sc-ysboml-0 styles__ButtonSecondary-sc-125aivg-0 brTHah bxLMor" href="/sl/fort-union/1751">store info</a><button type="button" aria-label="Shop this store Fort Union" data-test="@store-locator/StoreCard/MakeItMyStoreBtn" class="styles__StyledBaseButtonInternal-sc-ysboml-0 styles__ButtonSecondary-sc-125aivg-0 brTHah bxLMor">shop this store</button></div></div>

# %%
print((soup.find('span',class_ = 'h-display-inline-block')).prettify())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [48], in <cell line: 1>()
# ----> 1 print((soup.find('span',class_ = 'h-display-inline-block')).prettify())
#
# AttributeError: 'NoneType' object has no attribute 'prettify'

# %%
from bs4 import BeautifulSoup

# HTML code snippet with multiple elements containing aria-labels
html_code = '''
<div>
    <a href="https://www.bing.com/maps?ss=Target%2C+7025+S+Park+Centre+Dr%2C+Salt+Lake+City%2C+UT+84121-6619" target="_blank" aria-label="bing maps 7025 S Park Centre Dr, Salt Lake City, UT 84121-6619" class="styles__StyledLink-sc-vpsldm-0 eqjfDm h-text-grayDarkest" data-test="@store-locator/StoreAddress" rel="noopener">7025 S Park Centre Dr, Salt Lake City, UT 84121-6619</a>
</div>
<div>
    <a href="https://www.bing.com/maps?ss=Target%2C+1234+Main+St%2C+Anytown%2C+USA" target="_blank" aria-label="bing maps 1234 Main St, Anytown, USA" class="styles__StyledLink-sc-vpsldm-0 eqjfDm h-text-grayDarkest" data-test="@store-locator/StoreAddress" rel="noopener">1234 Main St, Anytown, USA</a>
</div>
'''

# Parse the HTML code using Beautiful Soup
soup = BeautifulSoup(html_code, 'html.parser')

# Extract all elements with aria-label attribute containing addresses
address_elements = soup.find_all(lambda tag: tag.has_attr('aria-label') and 'bing maps' in tag['aria-label'])

# Extract addresses from the aria-label attribute of each element
addresses = [element['aria-label'].split('bing maps ')[1] for element in address_elements]

# Print all extracted addresses
for address in addresses:
    print("Address:", address)
# Out:
# Address: 7025 S Park Centre Dr, Salt Lake City, UT 84121-6619
# Address: 1234 Main St, Anytown, USA

# %% [markdown]
# ## Selenium with Websdriver

# %%
from selenium import webdriver 
 
# initialize an instance of the chrome driver (browser)
driver = webdriver.Chrome()
# visit your target site
driver.get('https://scrapingclub.com/')

exercise_cards = driver.find_elements(By.CLASS_NAME, 'w-full.rounded.border')
# or
exercise_cards = driver.find_elements(By.CSS_SELECTOR, '.w-full.rounded.border')
# or
exercise_cards = driver.find_elements(By.XPATH, '/html/body/div[3]/div[2]/div/div[1]')

# release the resources allocated by Selenium and shut down the browser
driver.quit()

# %%
exercise_cards
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="c7bdd67e3c5557d92fc67ff002b78a85", element="f.591EAE6E087B74BC1BA734F585850E8A.d.5C8757C0766AF07A6A224C0ACEBD491B.e.8")>]

# %%
# headless mode, doesn't actually open the webbrowser
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# enable headless mode in Selenium
options = Options()
options.add_argument('--headless=new')

driver = webdriver.Chrome(
    options=options, 
    # other properties...
)

# %%
from selenium import webdriver 
from selenium.webdriver.chrome.options import Options
 
# initialize an instance of the chrome driver (browser)
driver = webdriver.Chrome()
# visit your target site
driver.get('https://www.target.com/store-locator/find-stores')

from selenium.webdriver.common.by import By

store_location = driver.find_elements(By.CLASS_NAME, "div") 
# or
# store_location_2 = driver.find_elements(By.CSS_SELECTOR, '#__next > div:nth-child(5) > div > div.h-display-flex.h-flex-wrap.h-padding-h-tight > div:nth-child(2) > div > div > span')
# or
# store_location_3 = driver.find_elements(By.XPATH, '//*[@id="__next"]/div[4]/div/div[3]/div[2]/div/div/span')

# release the resources allocated by Selenium and shut down the browser
driver.quit()

# %%
store_location
# Out:
# []

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select

import time

from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

test_url = 'https://www.target.com/store-locator/find-stores/30301'

options = Options()
options.add_argument('--headless=new')

# chromedriver = r'chromedriver_path'
browser = webdriver.Chrome(options=option)
browser.get(test_url)

time.sleep(5)

html_source = browser.page_source

browser.close()

# %%
soup=BeautifulSoup(html_source, "html.parser")

store_name_list_src = soup.find_all('h3', {'class','Heading__StyledHeading-sc-1mp23s9-0 Card__StoreCardTitle-sc-6da7hu-0 gcIYSr bEhCVm'})
store_name_list = []

# %%
addresses_src = soup.find_all('a',{'class', 'styles__StyledLink-sc-vpsldm-0 eqjfDm h-text-grayDarkest'})

addresses_src
# Out:
# [<a aria-label="bing maps 3535 Peachtree Rd NE, Atlanta, GA 30326-3287" class="styles__StyledLink-sc-vpsldm-0 eqjfDm h-text-grayDarkest" data-test="@store-locator/StoreAddress" href="https://www.bing.com/maps?ss=Target%2C+3535+Peachtree+Rd+NE%2C+Atlanta%2C+GA+30326-3287" rel="noopener" target="_blank">3535 Peachtree Rd NE, Atlanta, GA 30326-3287</a>,
#  <a class="styles__StyledLink-sc-vpsldm-0 eqjfDm h-text-grayDarkest" data-test="@store-locator/StorePhoneNumberLink" href="tel:+14042379494">404-237-9494</a>,
#  <a aria-label="bing maps 2539 Piedmont Rd NE, Atlanta, GA 30324-3006" class="styles__StyledLink-sc-vpsldm-0 eqjfDm h-text-grayDarkest" data-test="@store-locator/StoreAddress" href="https://www.bing.com/maps?ss=Target%2C+2539+Piedmont+Rd+NE%2C+Atlanta%2C+GA+30324-3006" rel="noopener" target="_blank">2539 Piedmont Rd NE, Atlanta, GA 30324-3006</a>,
# ...

# %%
type(addresses_src)
# Out:
# bs4.element.ResultSet

# %%
address_list = []

for val in addresses_src:
    address_list.append(val.get_text())
address_list
# Out:
# ['3535 Peachtree Rd NE, Atlanta, GA 30326-3287',
#  '404-237-9494',
#  '2539 Piedmont Rd NE, Atlanta, GA 30324-3006',
#  '404-720-1081',
#  '5570 Roswell Rd, Sandy Springs, GA 30342-1102',
#  '678-704-8120',
#  '375 18th St, Atlanta, GA 30363-1190',
#  '678-954-4265',
#  '2400 N Druid Hills Rd NE, Atlanta, GA 30329-3211',
#  '404-267-0060',
#  '2201 Cobb Pkwy SE, Smyrna, GA 30080-7633',
#  '770-952-2241',
#  '100 Perimeter Center Pl, Atlanta, GA 30346-1204',
#  '678-259-0888',
#  '1275 Caroline St NE, Atlanta, GA 30307-2705',
#  '404-260-0200',
#  '4241 Lavista Rd, Tucker, GA 30084-5310',
#  '770-270-5375',
#  '1401 Johnson Ferry Rd, Marietta, GA 30062-6495',
#  '770-240-0005',
#  '3200 Holcomb Bridge Rd, Peachtree Corners, GA 30092-3361',
#  '770-849-0885',
#  '4125 Austell Rd, Austell, GA 30106-1836',
#  '678-945-4550',
#  '3040 Shallowford Rd, Marietta, GA 30062-1252',
#  '770-321-8545',
#  '1135 Woodstock Rd, Roswell, GA 30075-2231',
#  '770-998-0144',
# ...

# %%
# from uszipcode import SearchEngine

# # Initialize the SearchEngine
# search = SearchEngine(simple_zipcode=True)

# # Get all zip codes in the US
# all_zipcodes = search.by_population()

# # Extract the zip codes from the result
# zipcodes_list = [zipcode.zipcode for zipcode in all_zipcodes]

# # Print the list of zip codes
# print(zipcodes_list)
# Out:
# /Users/kimbuesser/opt/anaconda3/lib/python3.9/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# Exception ignored in: <function SearchEngine.__del__ at 0x7fd199f96ca0>
# Traceback (most recent call last):
#   File "/Users/kimbuesser/opt/anaconda3/lib/python3.9/site-packages/uszipcode/search.py", line 195, in __del__
#     if self.ses:
# AttributeError: 'SearchEngine' object has no attribute 'ses'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [76], in <cell line: 4>()
#       1 from uszipcode import SearchEngine
#       3 # Initialize the SearchEngine
# ----> 4 search = SearchEngine(simple_zipcode=True)
#       6 # Get all zip codes in the US
# ...

# %%
# from uszipcode import SearchEngine

# # Initialize the SearchEngine
# search = SearchEngine()

# # Get all zip codes in the US
# all_zipcodes = search.simple_zipcode_list()

# # Extract the zip codes from the result
# zipcodes_list = [zipcode.zipcode for zipcode in all_zipcodes]

# # Print the list of zip codes
# print(zipcodes_list)
# Out:
# Download /Users/kimbuesser/.uszipcode/simple_db.sqlite from https://github.com/MacHu-GWU/uszipcode-project/releases/download/1.0.1.db/simple_db.sqlite ...
#   1.00 MB downloaded ...
#   2.00 MB downloaded ...
#   3.00 MB downloaded ...
#   4.00 MB downloaded ...
#   5.00 MB downloaded ...
#   6.00 MB downloaded ...
#   7.00 MB downloaded ...
#   8.00 MB downloaded ...
#   9.00 MB downloaded ...
#   10.00 MB downloaded ...
#   11.00 MB downloaded ...
#   Complete!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [77], in <cell line: 7>()
#       4 search = SearchEngine()
#       6 # Get all zip codes in the US
# ----> 7 all_zipcodes = search.simple_zipcode_list()
#       9 # Extract the zip codes from the result
#      10 zipcodes_list = [zipcode.zipcode for zipcode in all_zipcodes]
#
# AttributeError: 'SearchEngine' object has no attribute 'simple_zipcode_list'

# %%
zipcodes = pd.read_csv('/Users/kimbuesser/Downloads/ZIP_Locale_Detail.csv', converters={'DELIVERY ZIPCODE': str})
zipcode_list = zipcodes['DELIVERY ZIPCODE'].tolist()
zipcode_list
# Out:
# ['00601',
#  '00602',
#  '00603',
#  '00604',
#  '00605',
#  '00605',
#  '00606',
#  '00610',
#  '00611',
#  '00612',
#  '00613',
#  '00613',
#  '00614',
#  '00616',
#  '00617',
#  '00622',
#  '00623',
#  '00624',
#  '00627',
#  '00631',
#  '00637',
#  '00638',
#  '00641',
#  '00646',
#  '00647',
#  '00650',
#  '00652',
#  '00653',
#  '00656',
#  '00659',
#  '00660',
#  '00662',
#  '00664',
#  '00667',
#  '00669',
#  '00670',
#  '00674',
#  '00676',
#  '00676',
#  '00677',
#  '00678',
#  '00680',
#  '00680',
#  '00681',
#  '00681',
#  '00682',
#  '00683',
#  '00685',
#  '00685',
#  '00685',
#  '00687',
#  '00688',
#  '00690',
#  '00692',
#  '00692',
#  '00693',
#  '00694',
#  '00698',
#  '00703',
#  '00704',
#  '00705',
#  '00707',
#  '00714',
#  '00715',
#  '00716',
#  '00717',
#  '00718',
#  '00719',
#  '00720',
#  '00721',
#  '00723',
#  '00725',
#  '00725',
#  '00726',
#  '00726',
#  '00727',
#  '00727',
#  '00728',
#  '00729',
#  '00730',
#  '00731',
#  '00732',
#  '00732',
# ...

# %%
test_url = 'https://www.target.com/store-locator/find-stores/30301'
test_url_2 = f'https://www.target.com/store-locator/find-stores/{zipcode}'

# %%
for zipcode in zipcode_list:
    print(f'https://www.target.com/store-locator/find-stores/{zipcode}')
# Out:
# https://www.target.com/store-locator/find-stores/00601
# https://www.target.com/store-locator/find-stores/00602
# https://www.target.com/store-locator/find-stores/00603
# https://www.target.com/store-locator/find-stores/00604
# https://www.target.com/store-locator/find-stores/00605
# https://www.target.com/store-locator/find-stores/00605
# https://www.target.com/store-locator/find-stores/00606
# https://www.target.com/store-locator/find-stores/00610
# https://www.target.com/store-locator/find-stores/00611
# https://www.target.com/store-locator/find-stores/00612
# https://www.target.com/store-locator/find-stores/00613
# https://www.target.com/store-locator/find-stores/00613
# https://www.target.com/store-locator/find-stores/00614
# https://www.target.com/store-locator/find-stores/00616
# https://www.target.com/store-locator/find-stores/00617
# https://www.target.com/store-locator/find-stores/00622
# https://www.target.com/store-locator/find-stores/00623
# ...

# %%
web_address_list = []
for zipcode in zipcode_list:
    web_address_list.append(f'https://www.target.com/store-locator/find-stores/{zipcode}')
web_address_list
# Out:
# ['https://www.target.com/store-locator/find-stores/00601',
#  'https://www.target.com/store-locator/find-stores/00602',
#  'https://www.target.com/store-locator/find-stores/00603',
#  'https://www.target.com/store-locator/find-stores/00604',
#  'https://www.target.com/store-locator/find-stores/00605',
#  'https://www.target.com/store-locator/find-stores/00605',
#  'https://www.target.com/store-locator/find-stores/00606',
#  'https://www.target.com/store-locator/find-stores/00610',
#  'https://www.target.com/store-locator/find-stores/00611',
#  'https://www.target.com/store-locator/find-stores/00612',
#  'https://www.target.com/store-locator/find-stores/00613',
#  'https://www.target.com/store-locator/find-stores/00613',
#  'https://www.target.com/store-locator/find-stores/00614',
#  'https://www.target.com/store-locator/find-stores/00616',
#  'https://www.target.com/store-locator/find-stores/00617',
#  'https://www.target.com/store-locator/find-stores/00622',
# ...

# %%
# test_url = 'https://www.target.com/store-locator/find-stores/30301'
final_list = []

for address in web_address_list:
    try:
        options = Options()
        options.add_argument('--headless=new')

        # chromedriver = r'chromedriver_path'
        browser = webdriver.Chrome(options=option)
        browser.get(address)

        time.sleep(5)

        html_source = browser.page_source

        browser.close()

        soup=BeautifulSoup(html_source, "html.parser")

        addresses_src = soup.find_all('a',{'class', 'styles__StyledLink-sc-vpsldm-0 eqjfDm h-text-grayDarkest'})
        address_list = []

        for val in addresses_src:
            address_list.append(val.get_text())
#         final_list.append(addresses_src)
    except:
        pass
